# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani123-code/Open-cv-tutorial/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as mp
img = cv2.imread("/content/drive/MyDrive/OIP.jfif")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
img.shape
# Out:
# (296, 474, 3)

# %%
 from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=474x296 at 0x7F9B08A02E80>

# %%
cv2.waitKey(1)
# Out:
# -1

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=474x296 at 0x7F9AF865B970>

# %%
gray.shape
# Out:
# (296, 474)

# %%
img1 = img[:,:,1] 
img2 = img[:,:,2] 
img3 = img[:,:,0]

# %%
new = np.hstack((img1,img3,img2))

# %%
cv2_imshow(new)
# Out:
# <PIL.Image.Image image mode=L size=1422x296 at 0x7F9AF865B700>

# %%
img_res = cv2.resize(img,(256,200))

# %%
cv2_imshow(img_res)
# Out:
# <PIL.Image.Image image mode=RGB size=256x200 at 0x7F9B08A02E80>

# %%
img_res.shape
# Out:
# (200, 256, 3)

# %%
img_res1 = cv2.resize(img,(img.shape[1]//2,img.shape[0]//2))

# %%
cv2_imshow(img_res1)
# Out:
# <PIL.Image.Image image mode=RGB size=237x148 at 0x7F9B05A58AC0>

# %% [markdown]
# IMGAGE ROTATION
# O = VERTICAL
# 1 = HORIZONTAL
# -1  = BOTH

# %%
img_flip = cv2.flip(img,0)
cv2_imshow(img_flip)
# Out:
# <PIL.Image.Image image mode=RGB size=474x296 at 0x7F9B05A585B0>

# %%
img_flip = cv2.flip(img,1)
cv2_imshow(img_flip)
# Out:
# <PIL.Image.Image image mode=RGB size=474x296 at 0x7F9B08A02700>

# %%
img_flip = cv2.flip(img,-1)
cv2_imshow(img_flip)
# Out:
# <PIL.Image.Image image mode=RGB size=474x296 at 0x7F9B08A02A60>
